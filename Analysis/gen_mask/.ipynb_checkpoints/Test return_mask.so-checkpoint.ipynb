# %%
import healpy as h
from return_mask import gen_mask as gm

# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
gm.return_disc_mask?

# %%
mask=gm.return_disc_mask(15.3,2,512,8,343,h.nside2npix(512))

# %%
h.mollview(mask)
# Out:
# <img src="data:image/png;base64,..." width="850">
